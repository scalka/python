# %%
import pandas as pd
import json
import numpy as np

pd.options.display.max_rows = 10

# %%
recipes = pd.read_json('allrecipes-recipes.json', lines=True)
recipes
# Out:
#                   author  cook_time_minutes  \
# 0              Stephanie                 25
# 1              Stephanie                  0
# 2                  Kathy                  0
# 3          Mary E. Crain                  0
# 4                 DeeDee                 45
# ...                  ...                ...
# 225597         Maureen S                 20
# 225598         LadyBlitz                 20
# 225599  Back Porch Paleo                 25
# 225600             wilco                 10
# 225601          larkspur                 10
#
#                                               description  error  \
# 0       I just started adding my favorite things to ba...  False
# 1       These are great as an appetizer or served alon...  False
# 2       This is the best bread recipe.  Light and fluf...  False
# 3       A Southern delight with a 'more-ish'  taste.  ...  False
# 4       You can make these into braids or buns. Frost ...  False
# ...

# %%
#r = pd.read_json('github-allrecipes.data', lines=True)
#r

# %%
df_recipes = pd.DataFrame(recipes)

# %%
df_recipes.head()
# Out:
#           author  cook_time_minutes  \
# 0      Stephanie                 25
# 1      Stephanie                  0
# 2          Kathy                  0
# 3  Mary E. Crain                  0
# 4         DeeDee                 45
#
#                                          description  error  \
# 0  I just started adding my favorite things to ba...  False
# 1  These are great as an appetizer or served alon...  False
# 2  This is the best bread recipe.  Light and fluf...  False
# 3  A Southern delight with a 'more-ish'  taste.  ...  False
# 4  You can make these into braids or buns. Frost ...  False
#
#                                            footnotes  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [Cook's Note:, I made 1 braid, 12 cinnamon bun...
#
# ...

# %% [markdown]
# # EXPORT TO CSV

# %%
df_recipes.to_csv("allrecipes.csv")

# %%
df_recipes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10599 entries, 0 to 10598
# Data columns (total 17 columns):
# chef                        10599 non-null object
# chef_id                     10599 non-null object
# cooking_time_minutes        10599 non-null int64
# description                 10599 non-null object
# error                       10599 non-null bool
# ingredients                 10599 non-null object
# instructions                10599 non-null object
# instructions_detailed       10599 non-null object
# photo_url                   2225 non-null object
# preparation_time_minutes    10599 non-null int64
# program                     9626 non-null object
# program_id                  9626 non-null object
# serves                      10599 non-null int64
# time_scraped                10599 non-null int64
# title                       10599 non-null object
# total_time_minutes          10599 non-null int64
# url                         10599 non-null object
# ...

# %%
df_recipes.chef
# Out:
# 0             James Tanner
# 1               Mary Berry
# 2            Mari Williams
# 3         Justine Pattison
# 4         Ainsley Harriott
#                ...
# 10594         Andy Pearson
# 10595       Ching-He Huang
# 10596    Zoubida Boutarfas
# 10597           Janet Basu
# 10598     Gennaro Contaldo
# Name: chef, Length: 10599, dtype: object

# %%
df_recipes.chef.str.len()
# Out:
# 0        12
# 1        10
# 2        13
# 3        16
# 4        16
#          ..
# 10594    12
# 10595    14
# 10596    17
# 10597    10
# 10598    16
# Name: chef, Length: 10599, dtype: int64

# %%
df_recipes.ingredients
# Out:
# 0        [250g/8¾oz plain flour, plus extra for dusting...
# 1        [350g/12oz penne pasta, 2 x 80g/3oz packs Parm...
# 2        [200g/7oz unsalted soft butter, 200g/7oz caste...
# 3        [2.5kg/5lb 8oz turkey crown (fully thawed if f...
# 4        [2.25kg/5lb rib-eye of beef, boned and rolled,...
#                                ...
# 10594    [10 tbsp dark brown sugar, 300ml/10½fl oz lemo...
# 10595    [2 tbsp groundnut oil or vegetable oil, 5 garl...
# 10596    [2 tbsp olive oil, 1 x 1kg/2lb 4oz leg of lamb...
# 10597    l/18fl oz whole milk, 1 heaped tsp fast a...
# 10598    [6 free-range eggs, separated, 180g/6oz icing ...
# Name: ingredients, Length: 10599, dtype: object

# %%
pattern = 'Boutarfas'

# %%
df_recipes.chef.str.contains(pattern)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10594    False
# 10595    False
# 10596     True
# 10597    False
# 10598    False
# Name: chef, Length: 10599, dtype: bool

# %%
df_recipes.cooking_time_minutes < 10
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 10594     True
# 10595    False
# 10596    False
# 10597    False
# 10598     True
# Name: cooking_time_minutes, Length: 10599, dtype: bool

# %%
df_recipes[df_recipes.cooking_time_minutes > 30]
# Out:
#                                      chef                             chef_id  \
# 23                           Nigel Slater                        nigel_slater
# 70                            Delia Smith                         delia_smith
# 78     Andre Queiroz and Anderson Queiroz  andre_queiroz_and_anderson_queiroz
# 79                        Angela Boggiano                     angela_boggiano
# 83                        Angela Hartnett                     angela_hartnett
# ...                                   ...                                 ...
# 10547                      Jason Atherton                      jason_atherton
# 10556                         Yasmin Khan                         yasmin_khan
# 10571                        James Martin                        james_martin
# 10572                    The Hairy Bikers                        hairy_bikers
# 10596                   Zoubida Boutarfas                   zoubida_boutarfas
#
#        cooking_time_minutes  \
# ...

# %%
df_recipes[28:29]
# Out:
#            chef      chef_id  cooking_time_minutes description  error  \
# 28  Delia Smith  delia_smith                     0              False
#
#                                           ingredients  \
# 28  l/15fl oz milk - this can be infused but ...
#
#                                          instructions  \
# 28  [When you're ready to make the sauce, put the ...
#
#                                 instructions_detailed photo_url  \
# 28  [{'ingredient': 'milk', 'line': '425ml/15fl oz...      None
#
#     preparation_time_minutes program program_id  serves  time_scraped  \
# 28                        30    None       None     425    1499227808
#
#                      title  total_time_minutes  \
# 28  All-in-one white sauce                  30
#
#                                                   url
# 28  http://bbc.co.uk/food/recipes/allinonewhitesau...

# %% [markdown]
# ## what columns we want to retrieve

# %%
df_recipes.loc[df_recipes.total_time_minutes < 5, ['total_time_minutes', 'ingredients']]
# Out:
#        total_time_minutes                                        ingredients
# 27                      0  [500g/1Ib 2oz small currants, 140g/5oz raisins...
# 42                      0  [125g/4Â˝oz blanched almonds, 75g/3oz granulat...
# 77                      0  [1 medium to large pork fillet, 50g/1¾oz prune...
# 141                     0  [100g/3½oz sultanas, 50g/1¾oz chopped dried ap...
# 226                     0  [5 spring onions, roughly chopped, 4 garlic cl...
# ...                   ...                                                ...
# 10499                   0  [450g/1lb white cabbage, shredded, 200g/7oz re...
# 10539                   0  l/10fl oz double cream, 300ml/10fl oz ful...
# 10565                   0  [2 litres/3 pints whole milk, 1 lemon, juice o...
# 10578                   0  [2 good-quality strong, black tea bags, 4 tbsp...
# 10598                   0  [6 free-range eggs, separated, 180g/6oz icing ...
#
# [257 rows x 2 columns]

# %%
df_recipes.loc[ ( (df_recipes.ingredients.str.contains('onion')) | (df_recipes.ingredients.str.contains(''))), ['total_time_minutes', 'ingredients']]
# Out:
# Empty DataFrame
# Columns: [total_time_minutes, ingredients]
# Index: []
